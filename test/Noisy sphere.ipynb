# %%
using Meshes

# make sure we export to test/export
export_path = Pkg.dir("Meshes")*"/test/export/"
mkpath(export_path)

# Produce a level set function that is a noisy version of the distance from
# the origin (such that level sets are noisy spheres).
#
# The noise should exercise marching tetrahedra's ability to produce a water-
# tight surface in all cases (unlike standard marching cubes).
#
N = 10
sigma = 1.0
distance = Float32[ sqrt(float32(i*i+j*j+k*k)) for i = -N:N, j = -N:N, k = -N:N ]
distance = distance + sigma*rand(2*N+1,2*N+1,2*N+1)

# Extract an isosurface.
#
lambda = N-2*sigma # isovalue

msh = isosurface(distance,lambda)
# Out:
# Mesh([[18.7537,11.0,10.0],[4.1009,9.1009,11.0],[17.1184,13.0,8.0],[12.0,15.2109,17.0],[6.54345,5.0,12.0],[17.6611,14.0,9.0],[11.1444,16.1444,16.1444],[8.50211,9.0,4.0],[16.5022,7.0,14.5022],[8.0,10.7579,3.75794]  …  [13.0,12.0,18.1662],[13.0687,18.0687,10.0687],[4.36215,12.3622,7.36215],[15.7373,5.7373,13.7373],[14.0,3.7832,10.0],[11.7331,10.0,3.73312],[4.46685,8.0,11.0],[17.0,11.0,16.0267],[11.3412,12.3412,18.3412],[6.65722,14.0,5.65722]],[Face(1271,3429,1069),Face(1271,1274,2993),Face(1271,1069,1274),Face(1271,3233,3429),Face(1271,2993,2490),Face(1271,2490,3233),Face(2807,1370,619),Face(2807,2301,2067),Face(2807,619,2301),Face(1274,1069,1370)  …  Face(1793,2326,1488),Face(3141,579,2326),Face(3368,3149,2326),Face(579,3368,2326),Face(1412,1744,2560),Face(859,1518,2560),Face(1518,1412,2560),Face(1744,1488,2560),Face(3119,859,2560),Face(1488,3119,2560)],true)
